# %%
from fbCrawler.models import (Product, Members, Orders, Helper, Session, Group, Checkout, BankStatement,settlementRule)
from fbCrawler.utils import *
import pandas as pd
import os, json, datetime
from django.contrib.auth.models import User
from django.utils import timezone
from django.conf import settings
from django.utils.timezone import make_aware
from django.db.models import Q
import io
import csv

# %% [markdown]
# # 熱門度 View

# %%
session_id = '20190911'


# 物件關聯,兩種寫法
# session = Session.objects.get(session_id=session_id)
# ods = Orders.objects.filter(session=session).filter(~Q(amount=0))
ods = Orders.objects.filter(session__session_id=session_id).filter(~Q(amount=0))

# list(ods.values()),objects轉pandas
df_ods = pd.DataFrame(
    list(ods.values('member_id', 'member__name',
                    'product__wine_id', 'product__name', 'amount','product__product_article_link',
                    'product__price', 'product__erp_no')
         )
)
df_ods['order_total_price'] = df_ods['amount'] * \
                              df_ods['product__price']

#提取品項規則
sr = settlementRule.objects.filter(session=session_id)
df_sr = pd.DataFrame(
    list(sr.values('wineID', 'wineName', 'price', 'stockNum', 'stockNumFalse', 'limit', 'sale', 'deliverFree')))
df_sr = df_sr.set_index('wineID')

df_ods_group = df_ods.groupby(['product__wine_id','product__product_article_link'])['amount', 'order_total_price'].sum()
df_ods_group['bottleCount']  = df_ods.groupby(['product__wine_id','product__product_article_link'])['amount'].count()
df_ods_group=df_ods_group.reset_index().set_index('product__wine_id')
df = pd.concat([df_ods_group, df_sr], axis=1)
df['DSR'] = round((df['amount'].astype(int)) / (df['stockNumFalse'].astype(int)) * 100)  # 供需比
df['limit'] = df['limit'].apply(lambda s: str(s).replace('0', '無'))
df['bgc'] = ['#fccf80' if i > 100 else 'white' for i in df['DSR']]
df = df.sort_values('DSR', ascending=False)
df = df.reset_index()
df = df.rename(columns={'index': 'wine_id'})
df2 = df.T.to_dict().values()
context = {
    'datas': list(df2)
}
context
# Out:
# {'datas': [{'wine_id': '4520',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376136245940857/',
#    'amount': 148,
#    'order_total_price': 263440,
#    'bottleCount': 114,
#    'deliverFree': '0',
#    'limit': '1',
#    'price': '1780',
#    'sale': '0',
#    'stockNum': '25',
#    'stockNumFalse': '15',
#    'wineName': 'Ayala 2008 Rosé No.8 Brut Champagne',
#    'DSR': 987.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4521',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376139212607227/',
#    'amount': 159,
#    'order_total_price': 108120,
#    'bottleCount': 114,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '680',
#    'sale': '0',
#    'stockNum': '31',
#    'stockNumFalse': '19',
#    'wineName': 'Albert Bichot 2015 Bourgogne Vieilles Vignes紅',
#    'DSR': 837.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4490',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376138525940629/',
#    'amount': 59,
#    'order_total_price': 75520,
#    'bottleCount': 43,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1280',
#    'sale': '0',
#    'stockNum': '15',
#    'stockNumFalse': '9',
#    'wineName': 'Dumenil 2008 Brut 1er Cru Champagne香檳',
#    'DSR': 656.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4592',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376133585941123/',
#    'amount': 24,
#    'order_total_price': 42720,
#    'bottleCount': 23,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1780',
#    'sale': '0',
#    'stockNum': '6',
#    'stockNumFalse': '4',
#    'wineName': ' Marc Colin 2016 Chassagne-Montrachet "Margaux" 白',
#    'DSR': 600.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4871',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376126139275201/',
#    'amount': 34,
#    'order_total_price': 146880,
#    'bottleCount': 27,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '4320',
#    'sale': '0',
#    'stockNum': '10',
#    'stockNumFalse': '6',
#    'wineName': 'Bollinger 2008 La Grande Annee Brut Champagne伯蘭爵頂級年份香檳-贈送保冷袋',
#    'DSR': 567.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4610',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376122219275593/',
#    'amount': 20,
#    'order_total_price': 19000,
#    'bottleCount': 17,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '950',
#    'sale': '0',
#    'stockNum': '6',
#    'stockNumFalse': '4',
#    'wineName': 'Benedicte et Stephane Tissot 2017 Arbois DD Rouge',
#    'DSR': 500.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4525',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376137809274034/',
#    'amount': 163,
#    'order_total_price': 122250,
#    'bottleCount': 133,
#    'deliverFree': '0',
#    'limit': '1',
#    'price': '750',
#    'sale': '0',
#    'stockNum': '59',
#    'stockNumFalse': '35',
#    'wineName': 'Dominique Laurent 2015 Marsannay V.V. 紅',
#    'DSR': 466.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4527',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376135299274285/',
#    'amount': 18,
#    'order_total_price': 23400,
#    'bottleCount': 16,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1300',
#    'sale': '0',
#    'stockNum': '6',
#    'stockNumFalse': '4',
#    'wineName': 'Jean-Paul & Benoit Droin 2015 Chablis 1er Cru Montmains 白',
#    'DSR': 450.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4412',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376139549273860/',
#    'amount': 33,
#    'order_total_price': 28380,
#    'bottleCount': 27,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '860',
#    'sale': '0',
#    'stockNum': '14',
#    'stockNumFalse': '8',
#    'wineName': 'Domaine de Villaine 2016 Bouzeron Blanc 白',
#    'DSR': 412.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4479',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376140362607112/',
#    'amount': 24,
#    'order_total_price': 45120,
#    'bottleCount': 22,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1880',
#    'sale': '0',
#    'stockNum': '15',
#    'stockNumFalse': '9',
#    'wineName': 'Trimbach 2007 Riesling Cuvee Frederic Emile白',
#    'DSR': 267.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4609',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376121769275638/',
#    'amount': 10,
#    'order_total_price': 12500,
#    'bottleCount': 10,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1250',
#    'sale': '0',
#    'stockNum': '6',
#    'stockNumFalse': '4',
#    'wineName': 'Benedicte et Stephane Tissot 2016 Arbois Chardonnay Les Graviers',
#    'DSR': 250.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4534',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376140865940395/',
#    'amount': 52,
#    'order_total_price': 87360,
#    'bottleCount': 44,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1680',
#    'sale': '0',
#    'stockNum': '49',
#    'stockNumFalse': '29',
#    'wineName': 'Digioia Royer 2015 Chambolle Musigny 紅',
#    'DSR': 179.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4526',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376136022607546/',
#    'amount': 62,
#    'order_total_price': 89900,
#    'bottleCount': 42,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1450',
#    'sale': '0',
#    'stockNum': '59',
#    'stockNumFalse': '35',
#    'wineName': 'Dominique Laurent 2015 Nuits Saint Georges No.1 V.V.紅',
#    'DSR': 177.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4523',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376133032607845/',
#    'amount': 60,
#    'order_total_price': 36000,
#    'bottleCount': 55,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '600',
#    'sale': '0',
#    'stockNum': '60',
#    'stockNumFalse': '36',
#    'wineName': 'Chateau Pontus de Tyard 2016 Bourgogne Chardonnay “Clos De La Garenne” 白',
#    'DSR': 167.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4643',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376137262607422/',
#    'amount': 21,
#    'order_total_price': 69300,
#    'bottleCount': 15,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '3300',
#    'sale': '0',
#    'stockNum': '22',
#    'stockNumFalse': '13',
#    'wineName': 'Feuillet 2016 Chambolle Musigny 1er Cru Les Sentiers紅',
#    'DSR': 162.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4611',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376122402608908/',
#    'amount': 12,
#    'order_total_price': 15360,
#    'bottleCount': 12,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1280',
#    'sale': '0',
#    'stockNum': '14',
#    'stockNumFalse': '8',
#    'wineName': 'Benedicte et Stephane Tissot 2014 Arbois Savagnin Blanc',
#    'DSR': 150.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4496',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376138095940672/',
#    'amount': 57,
#    'order_total_price': 45600,
#    'bottleCount': 47,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '800',
#    'sale': '0',
#    'stockNum': '92',
#    'stockNumFalse': '55',
#    'wineName': 'La Chablisienne 2004 Chablis 1er Cru Fourchaume白',
#    'DSR': 104.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4537',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376134209274394/',
#    'amount': 111,
#    'order_total_price': 68820,
#    'bottleCount': 88,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '620',
#    'sale': '0',
#    'stockNum': '180',
#    'stockNumFalse': '108',
#    'wineName': 'Jean-Claude Bessin 2015 Chablis 白',
#    'DSR': 103.0,
#    'bgc': '#fccf80'},
#   {'wine_id': '4647',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376126689275146/',
#    'amount': 14,
#    'order_total_price': 75600,
#    'bottleCount': 14,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '5400',
#    'sale': '0',
#    'stockNum': '23',
#    'stockNumFalse': '14',
#    'wineName': 'Feuillet 2016 Echezeaux Grand Cru特級園',
#    'DSR': 100.0,
#    'bgc': 'white'},
#   {'wine_id': '4535',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376139005940581/',
#    'amount': 32,
#    'order_total_price': 40960,
#    'bottleCount': 29,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1280',
#    'sale': '0',
#    'stockNum': '57',
#    'stockNumFalse': '34',
#    'wineName': 'Digioia Royer 2015 Nuits Saint Georges “Les Charmois” 紅',
#    'DSR': 94.0,
#    'bgc': 'white'},
#   {'wine_id': '4303',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376130865941395/',
#    'amount': 32,
#    'order_total_price': 64000,
#    'bottleCount': 23,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '2000',
#    'sale': '0',
#    'stockNum': '60',
#    'stockNumFalse': '36',
#    'wineName': 'Mauro Molino 2015 Barolo Conca紅',
#    'DSR': 89.0,
#    'bgc': 'white'},
#   {'wine_id': '4323',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376140075940474/',
#    'amount': 37,
#    'order_total_price': 32930,
#    'bottleCount': 33,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '890',
#    'sale': '0',
#    'stockNum': '72',
#    'stockNumFalse': '43',
#    'wineName': 'Mee Godard 2017 Morgon “Cote du Py” 紅',
#    'DSR': 86.0,
#    'bgc': 'white'},
#   {'wine_id': '4473',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376141429273672/',
#    'amount': 209,
#    'order_total_price': 142120,
#    'bottleCount': 135,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '680',
#    'sale': '0',
#    'stockNum': '412',
#    'stockNumFalse': '247',
#    'wineName': 'Tenuta San Guido 2015 le Difese紅',
#    'DSR': 85.0,
#    'bgc': 'white'},
#   {'wine_id': '4528',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376135572607591/',
#    'amount': 20,
#    'order_total_price': 26000,
#    'bottleCount': 17,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1300',
#    'sale': '0',
#    'stockNum': '42',
#    'stockNumFalse': '25',
#    'wineName': 'Jean-Paul & Benoit Droin 2016 Chablis 1er Cru Vaulorent白',
#    'DSR': 80.0,
#    'bgc': 'white'},
#   {'wine_id': '4529',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376134409274374/',
#    'amount': 21,
#    'order_total_price': 19110,
#    'bottleCount': 16,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '910',
#    'sale': '0',
#    'stockNum': '52',
#    'stockNumFalse': '31',
#    'wineName': 'Jean-Paul & Benoit Droin 2017 Chablis 白',
#    'DSR': 68.0,
#    'bgc': 'white'},
#   {'wine_id': '4530',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376134739274341/',
#    'amount': 28,
#    'order_total_price': 20160,
#    'bottleCount': 22,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '720',
#    'sale': '0',
#    'stockNum': '72',
#    'stockNumFalse': '43',
#    'wineName': 'Jean-Paul & Benoit Droin 2017 Petit Chablis 白',
#    'DSR': 65.0,
#    'bgc': 'white'},
#   {'wine_id': '4644',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376137525940729/',
#    'amount': 22,
#    'order_total_price': 41360,
#    'bottleCount': 16,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1880',
#    'sale': '0',
#    'stockNum': '58',
#    'stockNumFalse': '35',
#    'wineName': 'Feuillet 2016 Chambolle Musigny紅',
#    'DSR': 63.0,
#    'bgc': 'white'},
#   {'wine_id': '4540',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376140579273757/',
#    'amount': 41,
#    'order_total_price': 51660,
#    'bottleCount': 38,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1260',
#    'sale': '0',
#    'stockNum': '120',
#    'stockNumFalse': '72',
#    'wineName': 'Sylvain Cholet 2016 Puligny Montrachet “Les Enseigneres”白',
#    'DSR': 57.0,
#    'bgc': 'white'},
#   {'wine_id': '4660',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376127182608430/',
#    'amount': 41,
#    'order_total_price': 28700,
#    'bottleCount': 31,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '700',
#    'sale': '0',
#    'stockNum': '120',
#    'stockNumFalse': '72',
#    'wineName': 'Jean Fournier 2017 Bourgogne Pinot Noir紅',
#    'DSR': 57.0,
#    'bgc': 'white'},
#   {'wine_id': '4512',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376138322607316/',
#    'amount': 18,
#    'order_total_price': 25200,
#    'bottleCount': 17,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1400',
#    'sale': '0',
#    'stockNum': '55',
#    'stockNumFalse': '33',
#    'wineName': ' Chateau des Quarts 2016 Pouilly Fuisse "Clos des Quarts" 獨佔(一級園)白酒',
#    'DSR': 55.0,
#    'bgc': 'white'},
#   {'wine_id': '4645',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376126909275124/',
#    'amount': 7,
#    'order_total_price': 46200,
#    'bottleCount': 7,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '6600',
#    'sale': '0',
#    'stockNum': '22',
#    'stockNumFalse': '13',
#    'wineName': 'Feuillet 2016 Charmes Chambertin Grand Cru特級園',
#    'DSR': 54.0,
#    'bgc': 'white'},
#   {'wine_id': '4506',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376129582608190/',
#    'amount': 68,
#    'order_total_price': 67320,
#    'bottleCount': 60,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '990',
#    'sale': '0',
#    'stockNum': '238',
#    'stockNumFalse': '143',
#    'wineName': "G. F. Duntze NV 'Legende' Blanc de Blancs 1er Cru Brut Champagne",
#    'DSR': 48.0,
#    'bgc': 'white'},
#   {'wine_id': '4300',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376132362607912/',
#    'amount': 34,
#    'order_total_price': 43520,
#    'bottleCount': 29,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1280',
#    'sale': '0',
#    'stockNum': '120',
#    'stockNumFalse': '72',
#    'wineName': 'Mauro Molino 2015 Barolo Gallinotto紅',
#    'DSR': 47.0,
#    'bgc': 'white'},
#   {'wine_id': '4662',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376128365941645/',
#    'amount': 16,
#    'order_total_price': 14560,
#    'bottleCount': 14,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '910',
#    'sale': '0',
#    'stockNum': '60',
#    'stockNumFalse': '36',
#    'wineName': 'Jean Fournier 2017 Marsannay Cuvee Saint Urbain紅',
#    'DSR': 44.0,
#    'bgc': 'white'},
#   {'wine_id': '4538',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376132752607873/',
#    'amount': 38,
#    'order_total_price': 22040,
#    'bottleCount': 29,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '580',
#    'sale': '0',
#    'stockNum': '156',
#    'stockNumFalse': '94',
#    'wineName': ' Sylvain Cholet 2016 Bourgogne Chardonnay "Les Grandes Gouttes"白',
#    'DSR': 40.0,
#    'bgc': 'white'},
#   {'wine_id': '4503',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376129069274908/',
#    'amount': 55,
#    'order_total_price': 52250,
#    'bottleCount': 49,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '950',
#    'sale': '0',
#    'stockNum': '239',
#    'stockNumFalse': '143',
#    'wineName': "G. F. Duntze NV 'Legende' Blanc de Noirs Brut Champagne",
#    'DSR': 38.0,
#    'bgc': 'white'},
#   {'wine_id': '4612',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376122632608885/',
#    'amount': 3,
#    'order_total_price': 3840,
#    'bottleCount': 3,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1280',
#    'sale': '0',
#    'stockNum': '14',
#    'stockNumFalse': '8',
#    'wineName': 'Benedicte et Stephane Tissot 2016 Cote du Jura “En Barberon” Chardonnay',
#    'DSR': 38.0,
#    'bgc': 'white'},
#   {'wine_id': '4646',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376126409275174/',
#    'amount': 8,
#    'order_total_price': 48000,
#    'bottleCount': 8,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '6000',
#    'sale': '0',
#    'stockNum': '35',
#    'stockNumFalse': '21',
#    'wineName': 'Feuillet 2016 Clos de la Roche 特級園',
#    'DSR': 38.0,
#    'bgc': 'white'},
#   {'wine_id': '4504',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376128662608282/',
#    'amount': 48,
#    'order_total_price': 47520,
#    'bottleCount': 43,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '990',
#    'sale': '0',
#    'stockNum': '239',
#    'stockNumFalse': '143',
#    'wineName': "G. F. Duntze NV 'Legende' 1er Cru Extra Brut Champagne",
#    'DSR': 34.0,
#    'bgc': 'white'},
#   {'wine_id': '4655',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376136475940834/',
#    'amount': 22,
#    'order_total_price': 32560,
#    'bottleCount': 19,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1480',
#    'sale': '0',
#    'stockNum': '108',
#    'stockNumFalse': '65',
#    'wineName': 'Feuillet 2014 Morey Saint Denis 紅',
#    'DSR': 34.0,
#    'bgc': 'white'},
#   {'wine_id': '4299',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376132575941224/',
#    'amount': 23,
#    'order_total_price': 24840,
#    'bottleCount': 20,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1080',
#    'sale': '0',
#    'stockNum': '120',
#    'stockNumFalse': '72',
#    'wineName': 'Mauro Molino 2015 Barolo紅',
#    'DSR': 32.0,
#    'bgc': 'white'},
#   {'wine_id': '4301',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376132022607946/',
#    'amount': 23,
#    'order_total_price': 33350,
#    'bottleCount': 20,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1450',
#    'sale': '0',
#    'stockNum': '120',
#    'stockNumFalse': '72',
#    'wineName': 'Mauro Molino 2015 Barolo Bricco Luciani 紅',
#    'DSR': 32.0,
#    'bgc': 'white'},
#   {'wine_id': '4302',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376131465941335/',
#    'amount': 11,
#    'order_total_price': 18590,
#    'bottleCount': 10,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1690',
#    'sale': '0',
#    'stockNum': '60',
#    'stockNumFalse': '36',
#    'wineName': 'Mauro Molino 2015 Barolo “La Serra”紅',
#    'DSR': 31.0,
#    'bgc': 'white'},
#   {'wine_id': '4666',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376127619275053/',
#    'amount': 20,
#    'order_total_price': 14000,
#    'bottleCount': 18,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '700',
#    'sale': '0',
#    'stockNum': '116',
#    'stockNumFalse': '70',
#    'wineName': 'Jean Fournier 2017 Marsannay Rose粉紅',
#    'DSR': 29.0,
#    'bgc': 'white'},
#   {'wine_id': '4505',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376129289274886/',
#    'amount': 42,
#    'order_total_price': 41580,
#    'bottleCount': 38,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '990',
#    'sale': '0',
#    'stockNum': '240',
#    'stockNumFalse': '144',
#    'wineName': "G. F. Duntze NV 'Legende' Rose Brut Champagne",
#    'DSR': 29.0,
#    'bgc': 'white'},
#   {'wine_id': '4694',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376125949275220/',
#    'amount': 19,
#    'order_total_price': 20900,
#    'bottleCount': 13,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1100',
#    'sale': '0',
#    'stockNum': '120',
#    'stockNumFalse': '72',
#    'wineName': 'Oremus 2017 Tokaji Furmint Late Harvest (500ml)',
#    'DSR': 26.0,
#    'bgc': 'white'},
#   {'wine_id': '4513',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376133939274421/',
#    'amount': 36,
#    'order_total_price': 97200,
#    'bottleCount': 33,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '2700',
#    'sale': '0',
#    'stockNum': '240',
#    'stockNumFalse': '144',
#    'wineName': "Domaine d'Ardhuy 2014 Corton-Charlemagne Grand Cru白",
#    'DSR': 25.0,
#    'bgc': 'white'},
#   {'wine_id': '4659',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376128102608338/',
#    'amount': 5,
#    'order_total_price': 5900,
#    'bottleCount': 5,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1180',
#    'sale': '0',
#    'stockNum': '36',
#    'stockNumFalse': '22',
#    'wineName': 'Jean Fournier 2017 Marsannay Clos du Roy白',
#    'DSR': 23.0,
#    'bgc': 'white'},
#   {'wine_id': '4665',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376127425941739/',
#    'amount': 8,
#    'order_total_price': 9440,
#    'bottleCount': 8,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1180',
#    'sale': '0',
#    'stockNum': '60',
#    'stockNumFalse': '36',
#    'wineName': 'Jean Fournier 2017 Marsannay Les Longeroies紅',
#    'DSR': 22.0,
#    'bgc': 'white'},
#   {'wine_id': '4692',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376125602608588/',
#    'amount': 13,
#    'order_total_price': 32500,
#    'bottleCount': 8,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '2500',
#    'sale': '0',
#    'stockNum': '101',
#    'stockNumFalse': '61',
#    'wineName': ' Cloudy Bay 2016 Pinot Noir "Te Wahi"紅',
#    'DSR': 21.0,
#    'bgc': 'white'},
#   {'wine_id': '4464',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376130469274768/',
#    'amount': 2,
#    'order_total_price': 31300,
#    'bottleCount': 2,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '15650',
#    'sale': '0',
#    'stockNum': '17',
#    'stockNumFalse': '10',
#    'wineName': 'Vega Sicilia “Unico” Reserva Especial R19 (2019 Release)',
#    'DSR': 20.0,
#    'bgc': 'white'},
#   {'wine_id': '4663',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376127862608362/',
#    'amount': 7,
#    'order_total_price': 8260,
#    'bottleCount': 7,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1180',
#    'sale': '0',
#    'stockNum': '60',
#    'stockNumFalse': '36',
#    'wineName': 'Jean Fournier 2017 Marsannay Clos du Roy紅',
#    'DSR': 19.0,
#    'bgc': 'white'},
#   {'wine_id': '4298',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376131769274638/',
#    'amount': 119,
#    'order_total_price': 69020,
#    'bottleCount': 91,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '580',
#    'sale': '0',
#    'stockNum': '1200',
#    'stockNumFalse': '720',
#    'wineName': 'Mauro Molino 2018 Roero Arneis DOCG 干白酒',
#    'DSR': 17.0,
#    'bgc': 'white'},
#   {'wine_id': '4466',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376129885941493/',
#    'amount': 8,
#    'order_total_price': 39600,
#    'bottleCount': 8,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '4950',
#    'sale': '0',
#    'stockNum': '96',
#    'stockNumFalse': '58',
#    'wineName': 'Vega Sicilia 2014 Valbuena 5',
#    'DSR': 14.0,
#    'bgc': 'white'},
#   {'wine_id': '4417',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376138775940604/',
#    'amount': 1,
#    'order_total_price': 3300,
#    'bottleCount': 1,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '3300',
#    'sale': '0',
#    'stockNum': '13',
#    'stockNumFalse': '8',
#    'wineName': 'Domaine Ponsot 2013 Clos des Monts Luisants Vieilles Vignes 一級園白酒',
#    'DSR': 12.0,
#    'bgc': 'white'},
#   {'wine_id': '4502',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376128859274929/',
#    'amount': 17,
#    'order_total_price': 16150,
#    'bottleCount': 16,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '950',
#    'sale': '0',
#    'stockNum': '239',
#    'stockNumFalse': '143',
#    'wineName': "G. F. Duntze NV 'Legende' Brut Champagne",
#    'DSR': 12.0,
#    'bgc': 'white'},
#   {'wine_id': '4670',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376123282608820/',
#    'amount': 7,
#    'order_total_price': 10500,
#    'bottleCount': 7,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1500',
#    'sale': '0',
#    'stockNum': '120',
#    'stockNumFalse': '72',
#    'wineName': 'Philippe Leclerc 2016 Chambolle Musigny “Les Babillaires”',
#    'DSR': 10.0,
#    'bgc': 'white'},
#   {'wine_id': '4667',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376122912608857/',
#    'amount': 31,
#    'order_total_price': 24800,
#    'bottleCount': 24,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '800',
#    'sale': '0',
#    'stockNum': '600',
#    'stockNumFalse': '360',
#    'wineName': 'Philippe Leclerc 2016 Bourgogne “Les Bons Batons”',
#    'DSR': 9.0,
#    'bgc': 'white'},
#   {'wine_id': '4668',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376123519275463/',
#    'amount': 6,
#    'order_total_price': 8280,
#    'bottleCount': 6,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1380',
#    'sale': '0',
#    'stockNum': '119',
#    'stockNumFalse': '71',
#    'wineName': 'Philippe Leclerc 2016 Gevrey Chambertin “Les Platieres”',
#    'DSR': 8.0,
#    'bgc': 'white'},
#   {'wine_id': '4671',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376124942608654/',
#    'amount': 3,
#    'order_total_price': 6840,
#    'bottleCount': 3,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '2280',
#    'sale': '0',
#    'stockNum': '60',
#    'stockNumFalse': '36',
#    'wineName': 'Philippe Leclerc 2016 Gevrey Chambertin 1er Cru “Les Champeaux”',
#    'DSR': 8.0,
#    'bgc': 'white'},
#   {'wine_id': '4672',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376125175941964/',
#    'amount': 5,
#    'order_total_price': 11500,
#    'bottleCount': 3,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '2300',
#    'sale': '0',
#    'stockNum': '120',
#    'stockNumFalse': '72',
#    'wineName': 'Philippe Leclerc 2016 Gevrey Chambertin 1er Cru “Les Cazetiers”',
#    'DSR': 7.0,
#    'bgc': 'white'},
#   {'wine_id': '4465',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376130195941462/',
#    'amount': 2,
#    'order_total_price': 25000,
#    'bottleCount': 2,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '12500',
#    'sale': '0',
#    'stockNum': '54',
#    'stockNumFalse': '32',
#    'wineName': 'Vega Sicilia 2009 Unico',
#    'DSR': 6.0,
#    'bgc': 'white'},
#   {'wine_id': '4669',
#    'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376124692608679/',
#    'amount': 3,
#    'order_total_price': 4950,
#    'bottleCount': 3,
#    'deliverFree': '0',
#    'limit': '無',
#    'price': '1650',
#    'sale': '0',
#    'stockNum': '119',
#    'stockNumFalse': '71',
#    'wineName': 'Philippe Leclerc 2016 Gevrey Chambertin “En Champs”',
#    'DSR': 4.0,
#    'bgc': 'white'}]}

# %% [markdown]
# # 銷售列表

# %%
currentSession = Session.objects.get(session_id='20190911')
ods = Orders.objects.filter(session=currentSession).filter(~Q(amount=0))
# ods = Orders.objects.filter(session__session_id=session_id).filter(~Q(amount=0))

# list(ods.values()),objects轉pandas
df_ods = pd.DataFrame(
    list(ods.values('member_id', 'member__name',
                    'product__wine_id', 'product__name', 'product__product_article_link', 'amount',
                    'product__price', 'product__erp_no')
         )
)
df_ods['order_total_price'] = df_ods['amount'] * \
                              df_ods['product__price']

sr = settlementRule.objects.filter(session=currentSession)
df_sr = pd.DataFrame(
    list(sr.values('wineID', 'wineName', 'price', 'stockNum', 'stockNumFalse', 'limit', 'sale', 'deliverFree')))
df_sr = df_sr.set_index('wineID')

df_ods_group = df_ods.groupby(['product__wine_id', 'product__product_article_link'])[
    'amount', 'order_total_price'].sum()
df_ods_group['bottleCount'] = df_ods.groupby(['product__wine_id', 'product__product_article_link'])[
    'amount'].count()
df_ods_group = df_ods_group.reset_index().set_index('product__wine_id')

df = pd.concat([df_ods_group, df_sr], axis=1)
df['DSR'] = round((df['amount'].astype(int)) / (df['stockNum'].astype(int)) * 100)  # 供需比
df['bgc'] = ['#fccf80' if i >= 100 else 'white' for i in df['DSR']]
df['limit'] = df['limit'].apply(lambda s: str(s).replace('0', '無'))
df['amount'] = df['amount'].astype(int)
df['stockNum'] = df['stockNum'].astype(int)
df['price'] = df['price'].astype(int)
df['saleVal'] = [s if v > s else v for v, s in zip(df['amount'], df['stockNum'])]
df['settle_total_price'] = df['saleVal'] * df['price']
df = df.sort_values('DSR', ascending=False)
df = df.reset_index()
df = df.rename(columns={'index': 'wine_id'})
df2 = df.T.to_dict().values()
context = {
    'session': currentSession,
    'datas': list(df2),
    'total_income': df['settle_total_price'].sum()
}
# Out:
# dict_values([{'wine_id': '4520', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376136245940857/', 'amount': 148, 'order_total_price': 263440, 'bottleCount': 114, 'deliverFree': '0', 'limit': '1', 'price': 1780, 'sale': '0', 'stockNum': 25, 'stockNumFalse': '15', 'wineName': 'Ayala 2008 Rosé No.8 Brut Champagne', 'DSR': 592.0, 'bgc': '#fccf80', 'saleVal': 25, 'settle_total_price': 44500}, {'wine_id': '4521', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376139212607227/', 'amount': 159, 'order_total_price': 108120, 'bottleCount': 114, 'deliverFree': '0', 'limit': '無', 'price': 680, 'sale': '0', 'stockNum': 31, 'stockNumFalse': '19', 'wineName': 'Albert Bichot 2015 Bourgogne Vieilles Vignes紅', 'DSR': 513.0, 'bgc': '#fccf80', 'saleVal': 31, 'settle_total_price': 21080}, {'wine_id': '4592', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376133585941123/', 'amount': 24, 'order_total_price': 42720, 'bottleCount': 23, 'deliverFree': '0', 'limit': '無', 'price': 1780, 'sale': '0', 'stockNum': 6, 'stockNumFalse': '4', 'wineName': ' Marc Colin 2016 Chassagne-Montrachet "Margaux" 白', 'DSR': 400.0, 'bgc': '#fccf80', 'saleVal': 6, 'settle_total_price': 10680}, {'wine_id': '4490', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376138525940629/', 'amount': 59, 'order_total_price': 75520, 'bottleCount': 43, 'deliverFree': '0', 'limit': '無', 'price': 1280, 'sale': '0', 'stockNum': 15, 'stockNumFalse': '9', 'wineName': 'Dumenil 2008 Brut 1er Cru Champagne香檳', 'DSR': 393.0, 'bgc': '#fccf80', 'saleVal': 15, 'settle_total_price': 19200}, {'wine_id': '4871', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376126139275201/', 'amount': 34, 'order_total_price': 146880, 'bottleCount': 27, 'deliverFree': '0', 'limit': '無', 'price': 4320, 'sale': '0', 'stockNum': 10, 'stockNumFalse': '6', 'wineName': 'Bollinger 2008 La Grande Annee Brut Champagne伯蘭爵頂級年份香檳-贈送保冷袋', 'DSR': 340.0, 'bgc': '#fccf80', 'saleVal': 10, 'settle_total_price': 43200}, {'wine_id': '4610', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376122219275593/', 'amount': 20, 'order_total_price': 19000, 'bottleCount': 17, 'deliverFree': '0', 'limit': '無', 'price': 950, 'sale': '0', 'stockNum': 6, 'stockNumFalse': '4', 'wineName': 'Benedicte et Stephane Tissot 2017 Arbois DD Rouge', 'DSR': 333.0, 'bgc': '#fccf80', 'saleVal': 6, 'settle_total_price': 5700}, {'wine_id': '4527', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376135299274285/', 'amount': 18, 'order_total_price': 23400, 'bottleCount': 16, 'deliverFree': '0', 'limit': '無', 'price': 1300, 'sale': '0', 'stockNum': 6, 'stockNumFalse': '4', 'wineName': 'Jean-Paul & Benoit Droin 2015 Chablis 1er Cru Montmains 白', 'DSR': 300.0, 'bgc': '#fccf80', 'saleVal': 6, 'settle_total_price': 7800}, {'wine_id': '4525', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376137809274034/', 'amount': 163, 'order_total_price': 122250, 'bottleCount': 133, 'deliverFree': '0', 'limit': '1', 'price': 750, 'sale': '0', 'stockNum': 59, 'stockNumFalse': '35', 'wineName': 'Dominique Laurent 2015 Marsannay V.V. 紅', 'DSR': 276.0, 'bgc': '#fccf80', 'saleVal': 59, 'settle_total_price': 44250}, {'wine_id': '4412', 'product__product_article_link': 'https://www.facebook.com/groups/1667261116828377/permalink/2376139549273860/', 'amount': 33, 'order_total_price': 28380, 'bottleCount': 27, 'deliverFree': '0', 'limit': '無', 'price': 860, 'sale': '0', 'stockNum': 14, 'stockNumFalse': '8', 'wineName': 'Domaine de Villaine 2016 Bouzeron Blanc 白', 'DSR': 236.0, 'bgc': '#fccf80', 'saleVal': 14, 'settle_total_price': 12040}, {'wine_id': '4609', 'product__product_article_link': 'https://www.facebook.com/groups/16672 ...

# %%
currentSession = Session.objects.get(session_id='20190911')
currentSession

# %%
# currentSession = Session.objects.get(session_id='20190911')
# sessionProducts = Product.objects.filter(session=currentSession)
# productList = list(sessionProducts)

# total_income = 0
# for product in productList:
#     productTotalOrders = Orders.objects.filter(
#         product=product).aggregate(Sum('amount'))['amount__sum']
#     product.totalOrders = productTotalOrders

#     productIncome = productTotalOrders*product.price
#     product.income = productIncome
#     total_income += productIncome

# context = {
#     'session': currentSession,
#     'products': productList,
#     'total_income': total_income
# }

# %%
context = {
    'message': None,
    'sessionExist': False,
    'hasOrder': False,
    'orders': None,
    'session': None,
    'member': None,
    'total_price': 0
}
# Session id 不存在
session_qs = Session.objects.filter(session_id=session_id)

if session_qs.count() == 0:
    context['message'] = '團次錯誤，請到團次列表查詢參與團次'
    return render(request, 'session/updateOrder.html', context=context)

session = session_qs[0]
if session.status != 'update_orders':
    context['message'] = '本團次目前沒有開放修正數量，有疑問請洽小幫手'
    return render(request, 'session/updateOrder.html', context=context)
else:
    context['sessionExist'] = True

session = session_qs[0]
member = Members.objects.get(user=request.user)
# 查詢此用戶在此 session 有無訂單
orders_qs = Orders.objects.filter(member=member, session=session)


if orders_qs.count() < 1:
    context['message'] = '您並無本團次訂單，有疑問請洽小幫手'
    return render(request, 'session/updateOrder.html', context=context)
else:
    context['hasOrder'] = True
    context['orders'] = orders_qs
    context['session'] = session
    context['member'] = member
    # total price
    total_price = 0
    for order in orders_qs:
        total_price += order.amount*order.product.price
    context['total_price'] = total_price

# %%
#物件關聯,兩種寫法
currentSession = Session.objects.get(session_id='20190911')
ods = Orders.objects.filter(session=currentSession)
# ods = Orders.objects.filter(session__session_id=session_id).filter(~Q(amount=0))

#list(ods.values()),objects轉pandas
df_ods = pd.DataFrame(
    list(ods.values('member_id', 'member__name', 
            'product__wine_id', 'product__name', 'amount',
            'product__price', 'product__erp_no')
    )
)

df_ods=df_ods.set_index('product__wine_id')
sr = settlementRule.objects.filter(session=currentSession)
df_sr=pd.DataFrame(list(sr.values('wineID','stockNum','stockNumFalse','limit','sale','deliverFree')))
df_sr=df_sr.set_index('wineID')
for i in ['stockNum','stockNumFalse','limit','sale','deliverFree']:
    df_ods[i]=df_sr[i]
df_ods_group=df_ods.groupby('product__wine_id')['amount'].sum()
df_ods['total_amount']=df_ods_group_count
df_ods['amount']=df_ods['amount'].astype(int)
df_ods['stockNumFalse']=df_ods['stockNumFalse'].astype(int)
df_ods['saleVal']=['#fccf80' if v>s else 'white' for v,s in zip(df_ods['total_amount'],df_ods['stockNumFalse'])]
df_ods

# df['limit']=df['limit'].apply(lambda s:str(s).replace('0','無'))
# df['amount']=df['amount'].astype(int)
# df['stockNum']=df['stockNum'].astype(int)
# df['price']=df['price'].astype(int)
# df['saleVal']=[s if v>s else v for v,s in zip(df['amount'],df['stockNum'])]
# df['settle_total_price']=df['saleVal']*df['price']
# df=df.sort_values('DSR',ascending=False)
# df=df.reset_index()
# df=df.rename(columns={'index':'wine_id'})
# df2=df.T.to_dict().values()



# context = {
#     'session': currentSession,
#     'datas': list(df2),
#     'total_income': df['settle_total_price'].sum()
# }


# context
